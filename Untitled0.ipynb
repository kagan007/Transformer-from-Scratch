# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

#hyperparameters
batch_size = 64
block_size = 256
max_iters = 3000
eval_interval = 10
learning_rate = 3e-4
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}") #
eval_iters = 50
n_embd = 384
n_head = 6
n_layer = 6
dropout = 0.2

torch.manual_seed(1337)

with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters integers
stoi = { ch:i for i,ch in enumerate(chars)}
itos = { i:ch for i,ch in enumerate(chars)}
encode = lambda s: [stoi[c] for c in s] #encoder: string -> integer
decode = lambda l: ''.join([itos[i] for i in l]) #decoder: integers -> string

#Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

#data loading
def get_batch(split):
    # generate a small batch of data of input x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size))) # mask future tokens for causal attention. no cheating lol
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B, T, C = x.shape
        k = self.key(x)
        q = self.query(x)
        # compute attention scores (affinities between all pairs of queries and keys)
        wei = q @ k.transpose(-2, -1) * k.shape[-1]**-0.5
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x)
        out = wei @ v
        return out

class MultiHeadAttention(nn.Module):

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)


    def forward(self, x):
        out =  torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedForward(nn.Module):
    """a simple linear layer followed by a non-linearity"""

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedForward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x


class GPTLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        # each token dırectly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layernorm
        self.lm_head = nn.Linear(n_embd, vocab_size)

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device))
        x = tok_emb + pos_emb
        x = self.blocks(x)
        x = self.ln_f(x)
        logits = self.lm_head(x)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            #make prediction
            idx_cond = idx[:, -block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            #apply softmax
            probs = F.softmax(logits, dim=-1)

            #sample from distribution
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

model = GPTLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

#create a pytorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

print("Starting training...")

for iter in range(max_iters):
    # periodically evaulate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    #evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

#generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=500)[0].tolist()))
# Out:
# Using device: cuda
# 10.788929 M parameters
# Starting training...
# step 0: train loss 4.2213, val loss 4.2304
# step 10: train loss 3.3149, val loss 3.3502
# step 20: train loss 3.1828, val loss 3.2129
# step 30: train loss 2.8651, val loss 2.8963
# step 40: train loss 2.6744, val loss 2.6816
# step 50: train loss 2.6001, val loss 2.5941
# step 60: train loss 2.5577, val loss 2.5628
# step 70: train loss 2.5303, val loss 2.5338
# step 80: train loss 2.5183, val loss 2.5151
# step 90: train loss 2.4969, val loss 2.5038
# step 100: train loss 2.4879, val loss 2.4977
# step 110: train loss 2.4714, val loss 2.4926
# step 120: train loss 2.4619, val loss 2.4685
# step 130: train loss 2.4563, val loss 2.4666
# step 140: train loss 2.4427, val loss 2.4643
# step 150: train loss 2.4461, val loss 2.4667
# step 160: train loss 2.4307, val loss 2.4540
# step 170: train loss 2.4229, val loss 2.4434
# step 180: train loss 2.4135, val loss 2.4415
# step 190: train loss 2.4096, val loss 2.4321
# step 200: train loss 2.3998, val loss 2.4246
# step 210: train loss 2.3846, val loss 2.4152
# step 220: train loss 2.3817, val loss 2.4132
# step 230: train loss 2.3736, val loss 2.4054
# step 240: train loss 2.3536, val loss 2.3911
# step 250: train loss 2.3388, val loss 2.3747
# step 260: train loss 2.3210, val loss 2.3602
# step 270: train loss 2.3105, val loss 2.3467
# step 280: train loss 2.2771, val loss 2.3208
# step 290: train loss 2.2611, val loss 2.3007
# step 300: train loss 2.2337, val loss 2.2840
# step 310: train loss 2.2137, val loss 2.2650
# step 320: train loss 2.1855, val loss 2.2431
# step 330: train loss 2.1705, val loss 2.2312
# step 340: train loss 2.1251, val loss 2.2045
# step 350: train loss 2.1014, val loss 2.1726
# step 360: train loss 2.0635, val loss 2.1329
# step 370: train loss 2.0295, val loss 2.1075
# step 380: train loss 1.9970, val loss 2.0911
# step 390: train loss 1.9743, val loss 2.0757
# step 400: train loss 1.9519, val loss 2.0585
# step 410: train loss 1.9238, val loss 2.0445
# step 420: train loss 1.9008, val loss 2.0267
# step 430: train loss 1.8820, val loss 1.9982
# step 440: train loss 1.8611, val loss 1.9915
# step 450: train loss 1.8340, val loss 1.9672
# step 460: train loss 1.8125, val loss 1.9532
# step 470: train loss 1.7985, val loss 1.9372
# step 480: train loss 1.7742, val loss 1.9143
# step 490: train loss 1.7710, val loss 1.9164
# step 500: train loss 1.7484, val loss 1.9003
# step 510: train loss 1.7399, val loss 1.8974
# step 520: train loss 1.7176, val loss 1.8669
# step 530: train loss 1.7044, val loss 1.8554
# step 540: train loss 1.6928, val loss 1.8467
# step 550: train loss 1.6730, val loss 1.8447
# step 560: train loss 1.6608, val loss 1.8318
# step 570: train loss 1.6489, val loss 1.8198
# step 580: train loss 1.6471, val loss 1.8158
# step 590: train loss 1.6361, val loss 1.7990
# step 600: train loss 1.6269, val loss 1.8088
# step 610: train loss 1.6182, val loss 1.7992
# step 620: train loss 1.6009, val loss 1.7849
# step 630: train loss 1.5942, val loss 1.7864
# step 640: train loss 1.5835, val loss 1.7761
# step 650: train loss 1.5806, val loss 1.7734
# step 660: train loss 1.5625, val loss 1.7502
# step 670: train loss 1.5645, val loss 1.7626
# step 680: train loss 1.5557, val loss 1.7489
# step 690: train loss 1.5450, val loss 1.7365
# step 700: train loss 1.5354, val loss 1.7227
# step 710: train loss 1.5300, val loss 1.7236
# step 720: train loss 1.5254, val loss 1.7143
# step 730: train loss 1.5227, val loss 1.7116
# step 740: train loss 1.5064, val loss 1.7161
# step 750: train loss 1.5038, val loss 1.6974
# step 760: train loss 1.5021, val loss 1.7035
# step 770: train loss 1.4936, val loss 1.6912
# step 780: train loss 1.4863, val loss 1.6950
# step 790: train loss 1.4865, val loss 1.6946
# step 800: train loss 1.4782, val loss 1.6704
# step 810: train loss 1.4685, val loss 1.6718
# step 820: train loss 1.4692, val loss 1.6707
# step 830: train loss 1.4617, val loss 1.6715
# step 840: train loss 1.4533, val loss 1.6548
# step 850: train loss 1.4589, val loss 1.6504
# step 860: train loss 1.4436, val loss 1.6477
# step 870: train loss 1.4402, val loss 1.6403
# step 880: train loss 1.4398, val loss 1.6361
# step 890: train loss 1.4432, val loss 1.6420
# step 900: train loss 1.4314, val loss 1.6348
# step 910: train loss 1.4181, val loss 1.6251
# step 920: train loss 1.4226, val loss 1.6269
# step 930: train loss 1.4153, val loss 1.6184
# step 940: train loss 1.4137, val loss 1.6267
# step 950: train loss 1.4051, val loss 1.6138
# step 960: train loss 1.4022, val loss 1.6131
# step 970: train loss 1.4000, val loss 1.6045
# step 980: train loss 1.3978, val loss 1.6024
# step 990: train loss 1.3936, val loss 1.5985
# step 1000: train loss 1.3863, val loss 1.6085
# step 1010: train loss 1.3837, val loss 1.5945
# step 1020: train loss 1.3846, val loss 1.6084
# step 1030: train loss 1.3797, val loss 1.6133
# step 1040: train loss 1.3757, val loss 1.5983
# step 1050: train loss 1.3749, val loss 1.6021
# step 1060: train loss 1.3676, val loss 1.5816
# step 1070: train loss 1.3674, val loss 1.5882
# step 1080: train loss 1.3603, val loss 1.5879
# step 1090: train loss 1.3643, val loss 1.5838
# step 1100: train loss 1.3536, val loss 1.5799
# step 1110: train loss 1.3574, val loss 1.5791
# step 1120: train loss 1.3484, val loss 1.5745
# step 1130: train loss 1.3472, val loss 1.5730
# step 1140: train loss 1.3492, val loss 1.5703
# step 1150: train loss 1.3450, val loss 1.5819
# step 1160: train loss 1.3405, val loss 1.5747
# step 1170: train loss 1.3337, val loss 1.5580
# step 1180: train loss 1.3345, val loss 1.5624
# step 1190: train loss 1.3279, val loss 1.5539
# step 1200: train loss 1.3318, val loss 1.5675
# step 1210: train loss 1.3242, val loss 1.5563
# step 1220: train loss 1.3261, val loss 1.5602
# step 1230: train loss 1.3217, val loss 1.5631
# step 1240: train loss 1.3225, val loss 1.5683
# step 1250: train loss 1.3197, val loss 1.5524
# step 1260: train loss 1.3154, val loss 1.5504
# step 1270: train loss 1.3116, val loss 1.5454
# step 1280: train loss 1.3081, val loss 1.5474
# step 1290: train loss 1.3105, val loss 1.5398
# step 1300: train loss 1.3017, val loss 1.5429
# step 1310: train loss 1.3078, val loss 1.5429
# step 1320: train loss 1.3011, val loss 1.5413
# step 1330: train loss 1.3101, val loss 1.5540
# step 1340: train loss 1.2921, val loss 1.5388
# step 1350: train loss 1.2970, val loss 1.5459
# step 1360: train loss 1.2886, val loss 1.5405
# step 1370: train loss 1.2870, val loss 1.5366
# step 1380: train loss 1.2862, val loss 1.5467
# step 1390: train loss 1.2878, val loss 1.5372
# step 1400: train loss 1.2829, val loss 1.5406
# step 1410: train loss 1.2840, val loss 1.5470
# step 1420: train loss 1.2804, val loss 1.5384
# step 1430: train loss 1.2855, val loss 1.5348
# step 1440: train loss 1.2818, val loss 1.5370
# step 1450: train loss 1.2730, val loss 1.5248
# step 1460: train loss 1.2769, val loss 1.5279
# step 1470: train loss 1.2695, val loss 1.5308
# step 1480: train loss 1.2738, val loss 1.5411
# step 1490: train loss 1.2689, val loss 1.5296
# step 1500: train loss 1.2650, val loss 1.5342
# step 1510: train loss 1.2613, val loss 1.5319
# step 1520: train loss 1.2682, val loss 1.5218
# step 1530: train loss 1.2595, val loss 1.5179
# step 1540: train loss 1.2558, val loss 1.5367
# step 1550: train loss 1.2558, val loss 1.5224
# step 1560: train loss 1.2558, val loss 1.5209
# step 1570: train loss 1.2605, val loss 1.5398
# step 1580: train loss 1.2516, val loss 1.5314
# step 1590: train loss 1.2510, val loss 1.5299
# step 1600: train loss 1.2465, val loss 1.5276
# step 1610: train loss 1.2476, val loss 1.5147
# step 1620: train loss 1.2465, val loss 1.5127
# step 1630: train loss 1.2430, val loss 1.5152
# step 1640: train loss 1.2404, val loss 1.5029
# step 1650: train loss 1.2407, val loss 1.5251
# step 1660: train loss 1.2342, val loss 1.5148
# step 1670: train loss 1.2365, val loss 1.5199
# step 1680: train loss 1.2334, val loss 1.5181
# step 1690: train loss 1.2361, val loss 1.5194
# step 1700: train loss 1.2344, val loss 1.5116
# step 1710: train loss 1.2333, val loss 1.5060
# step 1720: train loss 1.2367, val loss 1.5189
# step 1730: train loss 1.2247, val loss 1.5016
# step 1740: train loss 1.2292, val loss 1.5188
# step 1750: train loss 1.2202, val loss 1.5008
# step 1760: train loss 1.2225, val loss 1.5005
# step 1770: train loss 1.2234, val loss 1.4982
# step 1780: train loss 1.2183, val loss 1.5040
# step 1790: train loss 1.2174, val loss 1.5144
# step 1800: train loss 1.2133, val loss 1.4960
# step 1810: train loss 1.2141, val loss 1.5099
# step 1820: train loss 1.2126, val loss 1.5055
# step 1830: train loss 1.2094, val loss 1.5087
# step 1840: train loss 1.2106, val loss 1.5016
# step 1850: train loss 1.2077, val loss 1.5073
# step 1860: train loss 1.2123, val loss 1.5068
# step 1870: train loss 1.2054, val loss 1.5232
# step 1880: train loss 1.2001, val loss 1.4948
# step 1890: train loss 1.2048, val loss 1.5046
# step 1900: train loss 1.2024, val loss 1.5046
# step 1910: train loss 1.1954, val loss 1.4935
# step 1920: train loss 1.2004, val loss 1.5070
# step 1930: train loss 1.1952, val loss 1.4994
# step 1940: train loss 1.1955, val loss 1.4993
# step 1950: train loss 1.1964, val loss 1.5014
# step 1960: train loss 1.1892, val loss 1.4999
# step 1970: train loss 1.1911, val loss 1.4834
# step 1980: train loss 1.1887, val loss 1.4933
# step 1990: train loss 1.1853, val loss 1.4935
# step 2000: train loss 1.1819, val loss 1.4994
# step 2010: train loss 1.1883, val loss 1.4972
# step 2020: train loss 1.1841, val loss 1.5038
# step 2030: train loss 1.1837, val loss 1.4867
# step 2040: train loss 1.1743, val loss 1.4957
# step 2050: train loss 1.1877, val loss 1.4927
# step 2060: train loss 1.1837, val loss 1.4983
# step 2070: train loss 1.1791, val loss 1.4936
# step 2080: train loss 1.1744, val loss 1.4881
# step 2090: train loss 1.1749, val loss 1.4881
# step 2100: train loss 1.1660, val loss 1.4843
# step 2110: train loss 1.1716, val loss 1.4883
# step 2120: train loss 1.1696, val loss 1.4864
# step 2130: train loss 1.1674, val loss 1.4997
# step 2140: train loss 1.1734, val loss 1.4841
# step 2150: train loss 1.1637, val loss 1.4854
# step 2160: train loss 1.1650, val loss 1.4936
# step 2170: train loss 1.1643, val loss 1.4963
# step 2180: train loss 1.1632, val loss 1.4975
# step 2190: train loss 1.1639, val loss 1.4872
# step 2200: train loss 1.1652, val loss 1.4883
# step 2210: train loss 1.1594, val loss 1.4897
# step 2220: train loss 1.1523, val loss 1.4828
# step 2230: train loss 1.1583, val loss 1.4887
# step 2240: train loss 1.1612, val loss 1.4976
# step 2250: train loss 1.1572, val loss 1.4832
# step 2260: train loss 1.1499, val loss 1.4860
# step 2270: train loss 1.1574, val loss 1.4913
# step 2280: train loss 1.1601, val loss 1.4940
# step 2290: train loss 1.1561, val loss 1.4948
# step 2300: train loss 1.1454, val loss 1.4921
# step 2310: train loss 1.1571, val loss 1.5047
# step 2320: train loss 1.1458, val loss 1.4822
# step 2330: train loss 1.1465, val loss 1.4820
# step 2340: train loss 1.1452, val loss 1.4919
# step 2350: train loss 1.1411, val loss 1.4882
# step 2360: train loss 1.1379, val loss 1.4902
# step 2370: train loss 1.1417, val loss 1.4908
# step 2380: train loss 1.1418, val loss 1.4973
# step 2390: train loss 1.1377, val loss 1.4890
# step 2400: train loss 1.1361, val loss 1.4794
# step 2410: train loss 1.1377, val loss 1.4857
# step 2420: train loss 1.1323, val loss 1.4796
# step 2430: train loss 1.1297, val loss 1.4939
# step 2440: train loss 1.1287, val loss 1.4937
# step 2450: train loss 1.1358, val loss 1.4945
# step 2460: train loss 1.1288, val loss 1.4880
# step 2470: train loss 1.1309, val loss 1.4973
# step 2480: train loss 1.1293, val loss 1.4972
# step 2490: train loss 1.1262, val loss 1.4749
# step 2500: train loss 1.1299, val loss 1.4956
# step 2510: train loss 1.1319, val loss 1.5001
# step 2520: train loss 1.1289, val loss 1.4848
# step 2530: train loss 1.1230, val loss 1.4865
# step 2540: train loss 1.1198, val loss 1.4849
# step 2550: train loss 1.1269, val loss 1.4778
# step 2560: train loss 1.1176, val loss 1.4878
# step 2570: train loss 1.1151, val loss 1.4697
# step 2580: train loss 1.1172, val loss 1.4901
# step 2590: train loss 1.1173, val loss 1.4945
# step 2600: train loss 1.1108, val loss 1.5040
# step 2610: train loss 1.1093, val loss 1.4944
# step 2620: train loss 1.1135, val loss 1.4885
# step 2630: train loss 1.1056, val loss 1.4791
# step 2640: train loss 1.1039, val loss 1.5086
# step 2650: train loss 1.1075, val loss 1.4822
# step 2660: train loss 1.1083, val loss 1.4944
# step 2670: train loss 1.1001, val loss 1.4975
# step 2680: train loss 1.1005, val loss 1.4873
# step 2690: train loss 1.1052, val loss 1.4909
# step 2700: train loss 1.1110, val loss 1.5081
# step 2710: train loss 1.1018, val loss 1.4885
# step 2720: train loss 1.1011, val loss 1.4839
# step 2730: train loss 1.1003, val loss 1.4969
# step 2740: train loss 1.0967, val loss 1.4913
# step 2750: train loss 1.1033, val loss 1.4910
# step 2760: train loss 1.0935, val loss 1.4871
# step 2770: train loss 1.0983, val loss 1.4815
# step 2780: train loss 1.0893, val loss 1.4905
# step 2790: train loss 1.0907, val loss 1.4905
# step 2800: train loss 1.0914, val loss 1.4942
# step 2810: train loss 1.0891, val loss 1.4882
# step 2820: train loss 1.0895, val loss 1.4915
# step 2830: train loss 1.0828, val loss 1.4871
# step 2840: train loss 1.0813, val loss 1.4823
# step 2850: train loss 1.0883, val loss 1.4945
# step 2860: train loss 1.0844, val loss 1.4869
# step 2870: train loss 1.0870, val loss 1.4823
# step 2880: train loss 1.0833, val loss 1.4977
# step 2890: train loss 1.0859, val loss 1.4815
# step 2900: train loss 1.0856, val loss 1.4889
# step 2910: train loss 1.0796, val loss 1.4854
# step 2920: train loss 1.0760, val loss 1.4988
# step 2930: train loss 1.0738, val loss 1.4907
# step 2940: train loss 1.0739, val loss 1.4903
# step 2950: train loss 1.0804, val loss 1.4951
# step 2960: train loss 1.0750, val loss 1.4906
# step 2970: train loss 1.0757, val loss 1.5034
# step 2980: train loss 1.0682, val loss 1.4857
# step 2990: train loss 1.0682, val loss 1.4940
# step 2999: train loss 1.0695, val loss 1.4870
#
# How his wife? When I breathe were a grain
# To do im call the sunst fruit for winters
# Your haisted strange therein to your goddes.
# Make membass your banish'd mother's fault you;
# That you compunes me, and that t we have estrain'd,
# That happy daces you must be a creep from ion;
# Cry 'lequoin,' manify you,
# Freel the love's better. How canst them, I'll indeed,
# Of thy sight term'd-up howill not to't him;
# Doing the empty of order on it,
# And yet I bury taked it delay well.
#
# Provost:
# How never he knows not
